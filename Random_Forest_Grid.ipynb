# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
inde=dataset[["age","bmi","children","sex_male","smoker_yes"]]

# %%
dep=dataset[["charges"]]

# %%
inde
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dep
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['friedman_mse','squared_error','absolute_error','poisson'],'max_features':['none','sqrt','log2'],'n_estimators':[10,20,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(inde,dep)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 60 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 46 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'none' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.82051014 0.82275251 0.83466533
#  0.82349586 0.8271455  0.83151849        nan        nan        nan
#  0.81633974 0.82167294 0.83278478 0.81206658 0.82850918 0.83318536
#         nan        nan        nan 0.81717854 0.82657732 0.83267008
#  0.81256302 0.82938752 0.83548237        nan        nan        nan
#  0.82076942 0.82618396 0.83392426 0.81425082 0.82621975 0.83239284]
#   warnings.warn(
# C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'squared_error',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['none', 'sqrt', 'log2'],
#                          'n_estimators': [10, 20, 100]},
#              verbose=3)

# %%
result=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(result)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005016      0.002682         0.000000        0.000000
# 1        0.006784      0.003066         0.000000        0.000000
# 2        0.004058      0.002052         0.000000        0.000000
# 3        0.077747      0.008095         0.009524        0.003100
# 4        0.125008      0.005563         0.011067        0.004221
# 5        0.563250      0.012819         0.029870        0.005158
# 6        0.059313      0.002490         0.005764        0.002578
# 7        0.112872      0.008217         0.010118        0.006439
# 8        0.570705      0.012350         0.026220        0.003240
# 9        0.002648      0.001542         0.000000        0.000000
# 10       0.003793      0.003635         0.000000        0.000000
# 11       0.003104      0.001856         0.000000        0.000000
# 12       0.060469      0.003336         0.010057        0.004806
# 13       0.116168      0.003256         0.009383        0.005253
# 14       0.569592      0.018360         0.027217        0.005926
# 15       0.063206      0.002334         0.006597        0.002593
# 16       0.113149      0.002306         0.010141        0.003475
# 17       0.535295      0.020492         0.025248        0.004730
# 18       0.002240      0.003403         0.000000        0.000000
# 19       0.002220      0.003005         0.000000        0.000000
# 20       0.002435      0.001441         0.000000        0.000000
# 21       0.190724      0.004412         0.009305        0.001772
# 22       0.336669      0.008869         0.007237        0.005142
# 23       2.573072      0.201612         0.037640        0.002005
# 24       0.173463      0.010563         0.005371        0.004879
# 25       0.494123      0.060227         0.012528        0.002811
# 26       2.705278      0.096996         0.028996        0.008008
# 27       0.001755      0.001565         0.000000        0.000000
# 28       0.002331      0.002027         0.000000        0.000000
# 29       0.004445      0.001865         0.000000        0.000000
# 30       0.096532      0.004427         0.014175        0.003994
# 31       0.188984      0.003414         0.014526        0.003705
# 32       0.918384      0.007816         0.034643        0.004128
# 33       0.100769      0.003127         0.010190        0.003313
# 34       0.192180      0.008390         0.010898        0.002950
# 35       0.865913      0.107991         0.028647        0.005707
#
#    param_criterion param_max_features param_n_estimators  \
# 0     friedman_mse               none                 10
# 1     friedman_mse               none                 20
# 2     friedman_mse               none                100
# 3     friedman_mse               sqrt                 10
# 4     friedman_mse               sqrt                 20
# 5     friedman_mse               sqrt                100
# 6     friedman_mse               log2                 10
# 7     friedman_mse               log2                 20
# 8     friedman_mse               log2                100
# 9    squared_error               none                 10
# 10   squared_error               none                 20
# 11   squared_error               none                100
# 12   squared_error               sqrt                 10
# 13   squared_error               sqrt                 20
# 14   squared_error               sqrt                100
# 15   squared_error               log2                 10
# 16   squared_error               log2                 20
# 17   squared_error               log2                100
# 18  absolute_error               none                 10
# 19  absolute_error               none                 20
# 20  absolute_error               none                100
# 21  absolute_error               sqrt                 10
# 22  absolute_error               sqrt                 20
# 23  absolute_error               sqrt                100
# 24  absolute_error               log2                 10
# 25  absolute_error               log2                 20
# 26  absolute_error               log2                100
# 27         poisson               none                 10
# 28         poisson               none                 20
# 29         poisson               none                100
# 30         poisson               sqrt                 10
# 31         poisson               sqrt                 20
# 32         poisson               sqrt                100
# 33         poisson               log2                 10
# 34         poisson               log2                 20
# 35         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 1   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 2   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 3   {'criterion': 'friedman_mse', 'max_features': ...           0.843647
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.839386
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.858972
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.844191
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.855584
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.854933
# 9   {'criterion': 'squared_error', 'max_features':...                NaN
# 10  {'criterion': 'squared_error', 'max_features':...                NaN
# 11  {'criterion': 'squared_error', 'max_features':...                NaN
# 12  {'criterion': 'squared_error', 'max_features':...           0.841669
# 13  {'criterion': 'squared_error', 'max_features':...           0.844796
# 14  {'criterion': 'squared_error', 'max_features':...           0.855241
# 15  {'criterion': 'squared_error', 'max_features':...           0.827709
# 16  {'criterion': 'squared_error', 'max_features':...           0.854292
# 17  {'criterion': 'squared_error', 'max_features':...           0.862108
# 18  {'criterion': 'absolute_error', 'max_features'...                NaN
# 19  {'criterion': 'absolute_error', 'max_features'...                NaN
# 20  {'criterion': 'absolute_error', 'max_features'...                NaN
# 21  {'criterion': 'absolute_error', 'max_features'...           0.844372
# 22  {'criterion': 'absolute_error', 'max_features'...           0.851946
# 23  {'criterion': 'absolute_error', 'max_features'...           0.855733
# 24  {'criterion': 'absolute_error', 'max_features'...           0.834148
# 25  {'criterion': 'absolute_error', 'max_features'...           0.852759
# 26  {'criterion': 'absolute_error', 'max_features'...           0.857707
# 27  {'criterion': 'poisson', 'max_features': 'none...                NaN
# 28  {'criterion': 'poisson', 'max_features': 'none...                NaN
# 29  {'criterion': 'poisson', 'max_features': 'none...                NaN
# 30  {'criterion': 'poisson', 'max_features': 'sqrt...           0.860103
# 31  {'criterion': 'poisson', 'max_features': 'sqrt...           0.851120
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857050
# 33  {'criterion': 'poisson', 'max_features': 'log2...           0.840891
# 34  {'criterion': 'poisson', 'max_features': 'log2...           0.856866
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.859127
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3            0.763742           0.846793           0.819181
# 4            0.769231           0.848719           0.824283
# 5            0.778890           0.859954           0.829708
# 6            0.786729           0.848430           0.818036
# 7            0.773426           0.852390           0.817818
# 8            0.778530           0.856087           0.827254
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12           0.771530           0.833486           0.813790
# 13           0.759468           0.848634           0.822310
# 14           0.780472           0.861934           0.825229
# 15           0.763025           0.832837           0.811892
# 16           0.779166           0.854547           0.825325
# 17           0.779883           0.855917           0.827841
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21           0.757891           0.825581           0.822536
# 22           0.776738           0.841183           0.828022
# 23           0.781846           0.860056           0.826691
# 24           0.750589           0.837623           0.811641
# 25           0.777943           0.849318           0.830130
# 26           0.783039           0.859235           0.829749
# 27                NaN                NaN                NaN
# 28                NaN                NaN                NaN
# 29                NaN                NaN                NaN
# 30           0.760595           0.846771           0.814641
# 31           0.771708           0.862663           0.816325
# 32           0.782788           0.860743           0.827326
# 33           0.763610           0.836910           0.802804
# 34           0.777772           0.845351           0.819525
# 35           0.780075           0.858234           0.827767
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               25
# 1                 NaN              NaN             NaN               25
# 2                 NaN              NaN             NaN               25
# 3            0.829187         0.820510        0.030086               19
# 4            0.832144         0.822753        0.027950               16
# 5            0.845801         0.834665        0.029966                2
# 6            0.820092         0.823496        0.022105               15
# 7            0.836510         0.827146        0.030022               11
# 8            0.840788         0.831518        0.028509                8
# 9                 NaN              NaN             NaN               25
# 10                NaN              NaN             NaN               25
# 11                NaN              NaN             NaN               25
# 12           0.821224         0.816340        0.024388               21
# 13           0.833156         0.821673        0.032445               17
# 14           0.841048         0.832785        0.029038                5
# 15           0.824869         0.812067        0.025476               24
# 16           0.829216         0.828509        0.027525               10
# 17           0.840178         0.833185        0.029230                4
# 18                NaN              NaN             NaN               25
# 19                NaN              NaN             NaN               25
# 20                NaN              NaN             NaN               25
# 21           0.835512         0.817179        0.030627               20
# 22           0.834997         0.826577        0.026130               12
# 23           0.839025         0.832670        0.028075                6
# 24           0.828814         0.812563        0.032248               23
# 25           0.836788         0.829388        0.027001                9
# 26           0.847682         0.835482        0.028250                1
# 27                NaN              NaN             NaN               25
# 28                NaN              NaN             NaN               25
# 29                NaN              NaN             NaN               25
# 30           0.821737         0.820769        0.034301               18
# 31           0.829104         0.826184        0.031705               14
# 32           0.841714         0.833924        0.028189                3
# 33           0.827039         0.814251        0.028573               22
# 34           0.831585         0.826220        0.027298               13
# 35           0.836761         0.832393        0.028845                7

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children"))
sex_male_input=int(input("Sex_Male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 36
# BMI: 26
# Children 4
# Sex_Male 0 or 1: 1
# Smoker yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[21287.1986811]
# C:\Users\ManojGowdru\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
